# %%
import plotly.figure_factory as ff

import numpy as np
import pandas as pd

# %%
df = pd.read_csv('crude_rate.csv')

# %%
df = df.replace('Suppressed', 0)
df
# Out:
#          State  Year Deaths  Population  Crude Rate  \
# 0      Alabama  1999     39     4430141         0.9
# 1      Alabama  2000     46     4447100           1
# 2      Alabama  2001     67     4467634         1.5
# 3      Alabama  2002     75     4480089         1.7
# 4      Alabama  2003     54     4503491         1.2
# 5      Alabama  2004     92     4530729           2
# 6      Alabama  2005     83     4569805         1.8
# 7      Alabama  2006    134     4628981         2.9
# 8      Alabama  2007    172     4672840         3.7
# 9      Alabama  2008    195     4718206         4.1
# 10     Alabama  2009    210     4757938         4.4
# 11     Alabama  2010    194     4779736         4.1
# 12     Alabama  2011    180     4802740         3.7
# 13     Alabama  2012    175     4822023         3.6
# 14     Alabama  2013    175     4833722         3.6
# 15     Alabama  2014    282     4849377         5.8
# 16      Alaska  1999     28      624779         4.5
# ...

# %%
df_2003 = df.loc[df["Year"] == 2003]

# %%
len(df_2003)
# Out:
# 51

# %%
df_2003
# Out:
#          State  Year Deaths  Population  Crude Rate  \
# 0      Alabama  1999     39     4430141         0.9
# 1      Alabama  2000     46     4447100           1
# 2      Alabama  2001     67     4467634         1.5
# 3      Alabama  2002     75     4480089         1.7
# 4      Alabama  2003     54     4503491         1.2
# 5      Alabama  2004     92     4530729           2
# 6      Alabama  2005     83     4569805         1.8
# 7      Alabama  2006    134     4628981         2.9
# 8      Alabama  2007    172     4672840         3.7
# 9      Alabama  2008    195     4718206         4.1
# 10     Alabama  2009    210     4757938         4.4
# 11     Alabama  2010    194     4779736         4.1
# 12     Alabama  2011    180     4802740         3.7
# 13     Alabama  2012    175     4822023         3.6
# 14     Alabama  2013    175     4833722         3.6
# 15     Alabama  2014    282     4849377         5.8
# 16      Alaska  1999     28      624779         4.5
# ...

# %%
df_2003['code'] = ['AL',
 'AK',
 'AZ',
 'AR',
 'CA',
 'CO',
 'CT',
 'DE',
 'DD',     
 'FL',
 'GA',
 'HI',
 'ID',
 'IL',
 'IN',
 'IA',
 'KS',
 'KY',
 'LA',
 'ME',
 'MD',
 'MA',
 'MI',
 'MN',
 'MS',
 'MO',
 'MT',
 'NE',
 'NV',
 'NH',
 'NJ',
 'NM',
 'NY',
 'NC',
 'ND',
 'OH',
 'OK',
 'OR',
 'PA',
 'RI',
 'SC',
 'SD',
 'TN',
 'TX',
 'UT',
 'VT',
 'VA',
 'WA',
 'WV',
 'WI',
 'WY']

# %%
df_2003.columns
# Out:
# Index(['State', 'Year', 'Deaths', 'Population', 'Crude Rate',
#        'Crude Rate Lower 95% Confidence Interval',
#        'Crude Rate Upper 95% Confidence Interval',
#        'Prescriptions Dispensed by US Retailers in that year (millions)',
#        'code'],
#       dtype='object')

# %%
colorscale = ["#f7fbff","#ebf3fb","#deebf7","#d2e3f3","#c6dbef","#b3d2e9","#9ecae1",
              "#85bcdb","#6baed6","#57a0ce","#4292c6","#3082be","#2171b5","#1361a9",
              "#08519c","#0b4083","#08306b"]

# %%
endpts = list(np.linspace(1, 12, len(colorscale) - 1))
fips = df_2003['code'].tolist()
values = df_2003['Deaths'].tolist()

# %%
fig = ff.create_choropleth(
    fips=fips,
    values= values,

    binning_endpoints=endpts,
    colorscale=colorscale,
    show_state_data=True,
    show_hover=True, centroid_marker={'opacity': 1},
    asp=4.9, title='USA by Unemployment %',
    legend_title='% unemployed'
)

fig.layout.template = None
fig.show()
# Out:
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:6692: FutureWarning:
#
# Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-b0447d8da796> in <module>
#       8     show_hover=True, centroid_marker={'opacity': 1},
#       9     asp=4.9, title='USA by Unemployment %',
# ---> 10     legend_title='% unemployed'
#      11 )
#      12
#
# ...

# %%
df_sample.head()
df_sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58967 entries, 0 to 58966
# Data columns (total 7 columns):
# County         58967 non-null object
# County Code    58967 non-null int64
# Year           58967 non-null int64
# Year Code      58967 non-null int64
# Deaths         58967 non-null int64
# Population     58967 non-null int64
# Crude Rate     58967 non-null object
# dtypes: int64(5), object(2)
# memory usage: 3.1+ MB

# %%
df_try = df_sample[df_sample["Year"] == 2017]

# %%
df = pd.read_csv('overdose_county.csv')
df_sample = df[df["Year"] == 2003]

# %%
df_sample.head()
# Out:
#                 County  County Code  Year  Year Code  Deaths  Population  \
# 4   Autauga County, AL         1001  2003       2003     400       46800
# 23  Baldwin County, AL         1003  2003       2003    1505      151509
# 42  Barbour County, AL         1005  2003       2003     290       28594
# 61     Bibb County, AL         1007  2003       2003     228       21399
# 80   Blount County, AL         1009  2003       2003     557       53457
#
#    Crude Rate
# 4       854.7
# 23      993.3
# 42     1014.2
# 61     1065.5
# 80       1042

# %%
import plotly.graph_objects as go

# %%
df_1 = pd.read_csv('overdose_county.csv')

# %%
df_2= df_1[df_1["Year"] == 2003]

# %%
df_a = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/2011_us_ag_exports.csv')
df_a['code'] = df_a.code
len(df_a['code'])
# Out:
# 50

# %%
import plotly.graph_objects as go

fig = go.Figure(data=go.Choropleth(
    locations=df_2003['code'], # Spatial coordinates
    z = df_2003['Deaths'].astype(float), # Data to be color-coded
    locationmode = 'USA-states', # set of locations match entries in `locations`
    colorscale = 'Reds',
    colorbar_title = "Deaths",
))

fig.update_layout(
    title_text = '2003 US Death Overdoses by State',
    geo_scope='usa', # limite map scope to USA
)

fig.show()
# Out:
# <div>
#
#
#             <div id="00ff606d-f0ca-4c4e-9de4-a0c23c85af20" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("00ff606d-f0ca-4c4e-9de4-a0c23c85af20")) {
#                     Plotly.newPlot(
#                         '00ff606d-f0ca-4c4e-9de4-a0c23c85af20',
# ...
