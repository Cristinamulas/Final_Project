# %%
import pandas as pd
import seaborn as sns
import datetime
import warnings

# %%
# read crude rate df

# %%
df_crude_rate = pd.read_csv('crude_rate.csv')
df_crude_rate.head(20)
# Out:
#       State  Year      Deaths  Population  Crude Rate  \
# 0   Alabama  1999          39     4430141         0.9
# 1   Alabama  2000          46     4447100           1
# 2   Alabama  2001          67     4467634         1.5
# 3   Alabama  2002          75     4480089         1.7
# 4   Alabama  2003          54     4503491         1.2
# 5   Alabama  2004          92     4530729           2
# 6   Alabama  2005          83     4569805         1.8
# 7   Alabama  2006         134     4628981         2.9
# 8   Alabama  2007         172     4672840         3.7
# 9   Alabama  2008         195     4718206         4.1
# 10  Alabama  2009         210     4757938         4.4
# 11  Alabama  2010         194     4779736         4.1
# 12  Alabama  2011         180     4802740         3.7
# 13  Alabama  2012         175     4822023         3.6
# 14  Alabama  2013         175     4833722         3.6
# 15  Alabama  2014         282     4849377         5.8
# ...

# %%
# target crude rate do
df_crude_rate.head()
# df_crude_rate.Year
df_crude_rate.State.nunique()
# no null values
df_crude_rate.isnull().sum()
df_crude_rate.describe()
df_crude_rate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 8 columns):
# State                                                              816 non-null object
# Year                                                               816 non-null int64
# Deaths                                                             816 non-null object
# Population                                                         816 non-null int64
# Crude Rate                                                         816 non-null object
# Crude Rate Lower 95% Confidence Interval                           816 non-null object
# Crude Rate Upper 95% Confidence Interval                           816 non-null object
# Prescriptions Dispensed by US Retailers in that year (millions)    816 non-null int64
# dtypes: int64(3), object(5)
# memory usage: 51.1+ KB

# %%
# removing columns

# %%
# Rename columns
df_example = df_crude_rate.rename(columns = {'date': 'Year', 'Deaths': 'Deaths'})

# Group data by number of listings per date
# df_example = df_crude_rate.groupby(by = 'Deaths').agg({'ts': 'count'})

# Change index to datetime
df_example.Year.index = pd.to_datetime(df_example.Year.index)

# Set frequency of time series
# df_example = df_example.asfreq(freq='1D')

# Sort the values
# df_example = df_example.sort_index(ascending = True) 

# Fill values with 0
# df_example = df_example.fillna(value = 0)

# Show the end of the data
# display(df_example.tail())
df_example.columns
df_example = df_example.drop( columns = ['Population','Crude Rate','Crude Rate Lower 95% Confidence Interval' ,'Crude Rate Lower 95% Confidence Interval','Crude Rate Lower 95% Confidence Interval' ] , axis = 0)

# %%
df_example.head(10)
# Out:
#      State  Year Deaths Crude Rate Upper 95% Confidence Interval  \
# 0  Alabama  1999     39                                      1.2
# 1  Alabama  2000     46                                      1.4
# 2  Alabama  2001     67                                      1.9
# 3  Alabama  2002     75                                      2.1
# 4  Alabama  2003     54                                      1.6
# 5  Alabama  2004     92                                      2.5
# 6  Alabama  2005     83                                      2.3
# 7  Alabama  2006    134                                      3.4
# 8  Alabama  2007    172                                      4.2
# 9  Alabama  2008    195                                      4.7
#
#    Prescriptions Dispensed by US Retailers in that year (millions)
# 0                                                116
# 1                                                126
# 2                                                138
# ...

# %%
df_opio_clean.head()
# Out:
#                0                                          1  \
# 2       Location  Opioid Overdose Death Rate (Age-Adjusted)
# 3  United States                                       14.9
# 4        Alabama                                          9
# 5         Alaska                                       13.9
# 6        Arizona                                       13.5
#
#                                              2  \
# 2  All Drug Overdose Death Rate (Age-Adjusted)
# 3                                         21.7
# 4                                           18
# 5                                         20.2
# 6                                         22.2
#
#                                                    3  \
# 2  Percent Change in Opioid Overdose Death Rate f...
# 3                                               0.12
# 4                                                0.2
# 5                                               0.11
# ...

# %%
#  cleaning opio oversode table

# %%
col = ['Location', 'Opioid Overdose Death Rate (Age-Adjusted)','All Drug Overdose Death Rate (Age-Adjusted)','Percent Change in Opioid Overdose Death Rate','Percent Change in All Drug Overdose Death Rate']
df_opio = pd.read_csv('opioid_overdose.csv', header = None)
df_opio_clean  = pd.DataFrame(df_opio , copy = True)

# %%
# drop tittle 
df_opio_clean= df_opio_clean.drop(df_opio_clean.index[0])

# %%
# drop second column
df_opio_clean = df_opio_clean.drop(df_opio_clean.index[0])

# %%
# converting the first row into the header
df_opio_clean.columns = df_opio_clean.iloc[0]

# %%
df_opio_clean = df_opio_clean.drop(df_opio_clean.index[0])

# %%
df_opio_clean.head()
# Out:
# 2       Location Opioid Overdose Death Rate (Age-Adjusted)  \
# 3  United States                                      14.9
# 4        Alabama                                         9
# 5         Alaska                                      13.9
# 6        Arizona                                      13.5
# 7       Arkansas                                       6.5
#
# 2 All Drug Overdose Death Rate (Age-Adjusted)  \
# 3                                        21.7
# 4                                          18
# 5                                        20.2
# 6                                        22.2
# 7                                        15.5
#
# 2 Percent Change in Opioid Overdose Death Rate from Prior Year  \
# 3                                               0.12
# 4                                                0.2
# 5                                               0.11
# 6                                               0.18
# ...

# %%
df_opio_clean.describe()
# Out:
# 2           Location Opioid Overdose Death Rate (Age-Adjusted)  \
# count             60                                        52
# unique            60                                        49
# top     Rhode Island                                       5.1
# freq               1                                         2
#
# 2      All Drug Overdose Death Rate (Age-Adjusted)  \
# count                                           52
# unique                                          48
# top                                           11.7
# freq                                             2
#
# 2      Percent Change in Opioid Overdose Death Rate from Prior Year  \
# count                                                  52
# unique                                                 31
# top                                                 -0.05
# freq                                                    4
#
# 2      Percent Change in All Drug Overdose Death Rate from Prior Year
# ...

# %%
# Reading Accidental Drug Related Deaths table

# %%
df_deaths = pd.read_csv('Accidental_Drug_Related_Deaths_2012-2018.csv')

# %%
df_deaths.head()
# Out:
#         ID                    Date      DateType   Age     Sex          Race  \
# 0  14-0273  06/28/2014 12:00:00 AM  DateReported   NaN     NaN           NaN
# 1  13-0102  03/21/2013 12:00:00 AM   DateofDeath  48.0    Male         Black
# 2  16-0165  03/13/2016 12:00:00 AM   DateofDeath  30.0  Female         White
# 3  16-0208  03/31/2016 12:00:00 AM   DateofDeath  23.0    Male         White
# 4  13-0052  02/13/2013 12:00:00 AM   DateofDeath  22.0    Male  Asian, Other
#
#   ResidenceCity ResidenceCounty ResidenceState  DeathCity  ... Tramad  \
# 0           NaN             NaN            NaN        NaN  ...    NaN
# 1       NORWALK             NaN            NaN    NORWALK  ...    NaN
# 2    SANDY HOOK       FAIRFIELD             CT    DANBURY  ...    NaN
# 3           RYE     WESTCHESTER             NY  GREENWICH  ...    NaN
# 4      FLUSHING          QUEENS            NaN  GREENWICH  ...    NaN
#
#   Morphine_NotHeroin Hydromorphone Other OpiateNOS AnyOpioid MannerofDeath  \
# ...

# %%
df_deaths.ResidenceCity.value_counts()
# Out:
# HARTFORD               296
# WATERBURY              269
# BRIDGEPORT             241
# NEW HAVEN              224
# NEW BRITAIN            192
# BRISTOL                134
# MERIDEN                127
# NORWICH                109
# MANCHESTER             103
# TORRINGTON             100
# WEST HAVEN              91
# EAST HARTFORD           89
# MIDDLETOWN              88
# DANBURY                 86
# NEW LONDON              83
# ENFIELD                 80
# STRATFORD               80
# STAMFORD                67
# MILFORD                 62
# HAMDEN                  62
# NORWALK                 57
# NAUGATUCK               54
# WALLINGFORD             53
# GROTON                  50
# SOUTHINGTON             50
# SHELTON                 49
# WEST HARTFORD           46
# NEW MILFORD             45
# EAST HAVEN              44
# VERNON                  42
#                       ...
# MELBOURNE                1
# COSTA MESA               1
# HODGDON                  1
# ...

# %%
df_deaths.columns
# Out:
# Index(['ID', 'Date', 'DateType', 'Age', 'Sex', 'Race', 'ResidenceCity',
#        'ResidenceCounty', 'ResidenceState', 'DeathCity', 'DeathCounty',
#        'Location', 'LocationifOther', 'DescriptionofInjury', 'InjuryPlace',
#        'InjuryCity', 'InjuryCounty', 'InjuryState', 'COD', 'OtherSignifican',
#        'Heroin', 'Cocaine', 'Fentanyl', 'FentanylAnalogue', 'Oxycodone',
#        'Oxymorphone', 'Ethanol', 'Hydrocodone', 'Benzodiazepine', 'Methadone',
#        'Amphet', 'Tramad', 'Morphine_NotHeroin', 'Hydromorphone', 'Other',
#        'OpiateNOS', 'AnyOpioid', 'MannerofDeath', 'DeathCityGeo',
#        'ResidenceCityGeo', 'InjuryCityGeo'],
#       dtype='object')

# %%
# reading overdose by county table

# %%
df_overdose = pd.read_csv('overdose_county.csv')
# df_overdose.columns
# df_try= df_overdose.groupby('County Code')

# %%
len(df_overdose)
# Out:
# 58967

# %%
df_overdose.head(30)
# Out:
#                 County  County Code  Year  Year Code  Deaths  Population  \
# 0   Autauga County, AL         1001  1999       1999     361       42963
# 1   Autauga County, AL         1001  2000       2000     356       43671
# 2   Autauga County, AL         1001  2001       2001     362       44889
# 3   Autauga County, AL         1001  2002       2002     388       45909
# 4   Autauga County, AL         1001  2003       2003     400       46800
# 5   Autauga County, AL         1001  2004       2004     377       48366
# 6   Autauga County, AL         1001  2005       2005     454       49676
# 7   Autauga County, AL         1001  2006       2006     457       51328
# 8   Autauga County, AL         1001  2007       2007     406       52405
# 9   Autauga County, AL         1001  2008       2008     457       53277
# 10  Autauga County, AL         1001  2009       2009     412       54135
# 11  Autauga County, AL         1001  2010       2010     433       54571
# ...

# %%
len(df_try.County.unique())
# Out:
# 3133

# %%
# df.loc[df["State"] == 'Alabama', ["Year", "Deaths"]]
# Out:
# Empty DataFrame
# Columns: [County Code, Deaths]
# Index: []

# %%
len(df_census)
# Out:
# 65499

# %%
df_census = pd.read_csv('census.csv')

# %%
df_census.columns
# Out:
# Index(['CensusTract', 'State', 'County', 'TotalPop', 'Men', 'Women',
#        'Hispanic', 'White', 'Black', 'Native', 'Asian', 'Pacific', 'Citizen',
#        'Income', 'IncomeErr', 'IncomePerCap', 'IncomePerCapErr', 'Poverty',
#        'ChildPoverty', 'Professional', 'Service', 'Office', 'Construction',
#        'Production', 'Drive', 'Carpool', 'Transit', 'Walk', 'OtherTransp',
#        'WorkAtHome', 'MeanCommute', 'Employed', 'PrivateWork', 'PublicWork',
#        'SelfEmployed', 'FamilyWork', 'Unemployment'],
#       dtype='object')

# %%
df_census.isnull().sum()
# Out:
# CensusTract          0
# State                0
# County               0
# TotalPop             0
# Men                  0
# Women                0
# Hispanic           557
# White              557
# Black              557
# Native             557
# Asian              557
# Pacific            557
# Citizen              0
# Income             927
# IncomeErr          927
# IncomePerCap       601
# IncomePerCapErr    601
# Poverty            693
# ChildPoverty       953
# Professional       667
# Service            667
# Office             667
# Construction       667
# Production         667
# Drive              658
# Carpool            658
# Transit            658
# Walk               658
# OtherTransp        658
# WorkAtHome         658
# MeanCommute        796
# Employed             0
# PrivateWork        667
# PublicWork         667
# SelfEmployed       667
# FamilyWork         667
# Unemployment       662
# dtype: int64

# %%
df_census.head(50)
# Out:
#     CensusTract    State   County  TotalPop   Men  Women  Hispanic  White  \
# 0    1001020100  Alabama  Autauga      1948   940   1008       0.9   87.4
# 1    1001020200  Alabama  Autauga      2156  1059   1097       0.8   40.4
# 2    1001020300  Alabama  Autauga      2968  1364   1604       0.0   74.5
# 3    1001020400  Alabama  Autauga      4423  2172   2251      10.5   82.8
# 4    1001020500  Alabama  Autauga     10763  4922   5841       0.7   68.5
# 5    1001020600  Alabama  Autauga      3851  1787   2064      13.1   72.9
# 6    1001020700  Alabama  Autauga      2761  1210   1551       3.8   74.5
# 7    1001020801  Alabama  Autauga      3187  1502   1685       1.3   84.0
# 8    1001020802  Alabama  Autauga     10915  5486   5429       1.4   89.5
# 9    1001020900  Alabama  Autauga      5668  2897   2771       0.4   85.5
# 10   1001021000  Alabama  Autauga      3286  1740   1546       0.8   73.3
# 11   1001021100  Alabama  Autauga      3295  1666   1629       0.5   44.5
# ...

# %%
df_census.County.value_counts()
# Out:
# Los Angeles               2346
# Cook                      1326
# Maricopa                   916
# Orange                     903
# Jefferson                  884
# Montgomery                 817
# Harris                     791
# Kings                      788
# Wayne                      756
# Queens                     669
# San Diego                  628
# Clark                      582
# Dallas                     565
# Middlesex                  530
# Suffolk                    527
# Miami-Dade                 519
# Washington                 475
# Franklin                   464
# Riverside                  453
# Cuyahoga                   447
# Marion                     439
# Lake                       427
# Jackson                    424
# Hillsborough               407
# Allegheny                  402
# Essex                      386
# Philadelphia               384
# Monroe                     378
# Santa Clara                372
# San Bernardino             369
# ...

# %%
df_census.State.value_counts()
# Out:
# California              8057
# New York                4918
# Florida                 4245
# Texas                   3870
# Pennsylvania            3218
# Illinois                3123
# Ohio                    2952
# Michigan                2813
# North Carolina          2195
# New Jersey              2010
# Georgia                 1969
# Arizona                 1526
# Indiana                 1511
# Tennessee               1497
# Massachusetts           1478
# Maryland                1406
# Missouri                1393
# Minnesota               1338
# Colorado                1249
# Alabama                 1181
# Louisiana               1148
# Kentucky                1115
# South Carolina          1103
# Oklahoma                1046
# Oregon                   834
# Connecticut              833
# Iowa                     825
# Kansas                   770
# Nevada                   687
# Arkansas                 686
# Mississippi              664
# Nebraska                 532
# ...
